# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;
import seaborn as sns;

# %%
df = pd.read_excel("Online Retail.xlsx");

# %%
print(f"Dataset Shape: {df.shape}");
print(f"\n ---Data Types---");
print(df.dtypes);
# Out:
# Dataset Shape: (541909, 8)
#
#  ---Data Types---
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[us]
# UnitPrice             float64
# CustomerID            float64
# Country                   str
# dtype: object

# %%
print("\n ---Sample Data---");
print(df.head());
# Out:
#  ---Sample Data---
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
print(df.tail());
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %%
print("\n---Unique Counts per Coloumn---");
print(df.nunique());
# Out:
# ---Unique Counts per Coloumn---
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %%
print("\n ---Parsing InvoiceDate---");
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate']);
print(df['InvoiceDate'].dtype);
# Out:
#  ---Parsing InvoiceDate---
# datetime64[us]

# %%
print("\n --InvoiceNo cancellation codes--");
print(df['InvoiceNo'].str.startswith('C').count());
# Out:
#  --InvoiceNo cancellation codes--
# 9291

# %%
print("\n --No of Unique Customer Id's---");
print(df['CustomerID'].nunique());
# Out:
#  --No of Unique Customer Id's---
# 4372

# %%
print("\n--No of missing Customers--");
print(df['CustomerID'].isna().sum());
# Out:
# --No of missing Customers--
# 135080

# %%
print("\n --Product cardinality--");
print(df['StockCode'].nunique());
# Out:
#  --Product cardinality--
# 4070

# %%
print("\n --Country Cardinality-- ");
print(df['Country'].nunique());
# Out:
#  --Country Cardinality--
# 38

# %%
print("\n-- Missing value --");
print(df.isna().sum());
# Out:
# -- Missing value --
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
print("\n-- Adding of Transaction Column--");
df['TransactionValue'] = df['Quantity']*df['UnitPrice'];
print(df['TransactionValue'].head(10));
# Out:
# -- Adding of Transaction Column--
# 0    15.30
# 1    20.34
# 2    22.00
# 3    20.34
# 4    20.34
# 5    15.30
# 6    25.50
# 7    11.10
# 8    11.10
# 9    54.08
# Name: TransactionValue, dtype: float64

# %%
print(df)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df.to_excel('Updates_transaction.xlsx', index=False)
